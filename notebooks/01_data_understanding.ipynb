# %% [markdown]
# ## Data Understanding
#
# ### 1. Project Objective
#
# Understand the dataset structure before data cleaning and analysis.
#
# This notebook focuses on:
#
# - Understanding the dataset structure
# - Identifying available features
# - Reviewing numerical and categorical variables
# - Recording initial observations

# %% [markdown]
# ### 2. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ### 3. Load Dataset

# %%
df = pd.read_csv("../data/raw/Superstore.csv", encoding="ISO-8859-1")
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# The dataset contains order-level information, including sales,
# profit, customer, product and shipping information.

# %% [markdown]
# ### 4. Preview Dataset

# %%
df.tail(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9993    9994  CA-2014-119914  05-05-2014  10-05-2014    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.sample(5, random_state=42)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3125    3126  CA-2012-121720  11-06-2012  12-06-2012     First Class
# 1441    1442  CA-2014-128160  20-12-2014  25-12-2014    Second Class
# 4510    4511  CA-2013-119935  11-11-2013  15-11-2013  Standard Class
# 39        40  CA-2012-117415  27-12-2012  31-12-2012  Standard Class
# 4509    4510  CA-2014-167003  24-05-2014  30-05-2014  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 3125    JE-15610           Jim Epp    Corporate  United States       Lakeland
# 1441    MM-17920     Michael Moore     Consumer  United States  San Francisco
# 4510    KM-16225      Kalyca Meade    Corporate  United States    Springfield
# 39      SN-20710      Steve Nguyen  Home Office  United States        Houston
# 4509    VS-21820  Vivek Sundaresam     Consumer  United States    Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# The dataset appears to contain transaction-level retail sales records.

# %% [markdown]
# ### 5. Dataset Structure

# %%
rows, cols = df.shape

print(f"Rows: {rows}")
print(f"Columns: {cols}")
# Out:
# Rows: 9994
# Columns: 21

# %%
pd.DataFrame(df.columns, columns=["Column Name"])
# Out:
#       Column Name
# 0          Row ID
# 1        Order ID
# 2      Order Date
# 3       Ship Date
# 4       Ship Mode
# 5     Customer ID
# 6   Customer Name
# 7         Segment
# 8         Country
# 9            City
# 10          State
# 11    Postal Code
# 12         Region
# 13     Product ID
# 14       Category
# 15   Sub-Category
# 16   Product Name
# 17          Sales
# 18       Quantity
# 19       Discount
# 20         Profit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# Observation:
# - Most categorical columns are stored as object.
# - Date columns are also stored as object and will be converted during the data cleaning stage.

# %% [markdown]
# ### 6. Basic Statistics

# %%
df.describe().T
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %% [markdown]
# Sales and Profit show a wide range of values, indicating possible outliers.

# %% [markdown]
# ### 7. Categorical Overview

# %%
categorical_columns = df.select_dtypes(include="object").columns

pd.DataFrame(categorical_columns, columns=["Column Name"])
# Out:
#       Column Name
# 0        Order ID
# 1      Order Date
# 2       Ship Date
# 3       Ship Mode
# 4     Customer ID
# 5   Customer Name
# 6         Segment
# 7         Country
# 8            City
# 9           State
# 10         Region
# 11     Product ID
# 12       Category
# 13   Sub-Category
# 14   Product Name

# %%
unique_summary = pd.DataFrame({
    "Column": categorical_columns,
    "Unique Values": [
        df[col].nunique()
        for col in categorical_columns
    ]
})

unique_summary
# Out:
#            Column  Unique Values
# 0        Order ID           5009
# 1      Order Date           1238
# 2       Ship Date           1334
# 3       Ship Mode              4
# 4     Customer ID            793
# 5   Customer Name            793
# 6         Segment              3
# 7         Country              1
# 8            City            531
# 9           State             49
# 10         Region              4
# 11     Product ID           1862
# 12       Category              3
# 13   Sub-Category             17
# 14   Product Name           1841

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %% [markdown]
# ### 8. Initial Findings
#
# From the initial inspection:
#
# - The dataset contains retail order records.
# - There are 21 variables describing customers, products, orders and sales.
# - Numerical variables include Sales, Profit, Quantity and Discount.
# - Several categorical variables (Region, Segment, Category and Ship Mode) will be useful for business analysis.
# - Date columns are currently stored as object type and require conversion during data cleaning.
# - No conclusions about data quality or business performance are made at this stage.
